# %% [markdown]
# # Meta Ad-Policy RL Training Proof
# This notebook demonstrates the agent training on the environment. It runs the full inference loop across all test tasks.

# %%
# !python inference.py
# Out:
# [START] task=task_1_healthcare env=meta_ad_policy_sandbox model=meta-llama/Llama-3-70b-chat-hf
# [STEP] step=1 action=query_regulations reward=-0.05 done=false
# [STEP] step=2 action=check_crm reward=-0.05 done=false
# [STEP] step=3 action=log_audit reward=-0.05 done=false
# [STEP] step=4 action=reject reward=1.00 done=true
# [END] success=true steps=4 score=0.850 rewards=-0.05,-0.05,-0.05,1.00
# [START] task=task_2_financial env=meta_ad_policy_sandbox model=meta-llama/Llama-3-70b-chat-hf
# [STEP] step=1 action=query_regulations reward=-0.05 done=false
# [STEP] step=2 action=check_crm reward=-0.05 done=false
# [STEP] step=3 action=log_audit reward=-0.05 done=false
# [STEP] step=4 action=request_landing_page reward=-0.05 done=false
# [STEP] step=5 action=reject reward=1.00 done=true
# [END] success=true steps=5 score=0.800 rewards=-0.05,-0.05,-0.05,-0.05,1.00
# [START] task=task_3_multimodal env=meta_ad_policy_sandbox model=meta-llama/Llama-3-70b-chat-hf
# ...
